# %%
'''
This script extracts and updates census tract IDs for articles from the Boston Globe dataset for 
the year 2015 using coordinates. This script was run for all years
'''

# %%
# Importing the necessary libraries
import pandas as pd
import requests
from mapbox import Geocoder

# %%
# Loading Boston Globe dataset 
bostonGlobe_2015 = pd.read_csv('/Users/rachelgupta/Desktop/NAACP - PIT NE/pitne-bias-in-media/summer24/Data/Combined_Datasets_2/2015/Boston_Globe_2015_5000_articles_approx.csv')

# %%
# Setting the display precision for floating-point numbers in pandas DataFrames to 7 decimal places
pd.set_option('display.precision', 7)

# %%
# Function to safely extract and clean coordinates
def extract_coordinates(coord):
    if pd.isna(coord):
        return None, None
    lat, lon = coord.strip(' []').split(',')
    return float(lat), float(lon)

# %%
# Applying the function to extract latitude and longitude
bostonGlobe_2015[['longitude', 'latitude']] = bostonGlobe_2015['NER_Sorted_Coordinates'].apply(lambda x: pd.Series(extract_coordinates(x)))

# %%
# Droping rows where coordinates could not be extracted
bostonGlobe_2015.dropna(subset=['latitude', 'longitude'], inplace=True)

# %%
bostonGlobe_2015.head()
# Out:
#    Unnamed: 0                                              hl1_x  \
# 0           0                     ruling may aid tsarnaev appeal
# 2           2                                   sandoval the one
# 3           3                            long life long on deeds
# 4           4  the developer v. the penguins (and their ceo) ...
# 6           6                chism expressed remorse expert says
#
#                                                 body  \
# 0  both cases claim that the potential jurors wer...
# 2  but sandoval first year in boston was calamito...
# 3  my dad was one of those guys who didn talk muc...
# 4  the bigger the project the more you have to di...
# 6  caused the difficulties that he caused dr. dud...
#
#                                     llama_prediction Explicit_Pass_1  \
# 0    Based on the article provided, I would guess...             NaN
# 2    Based on the information provided in the art...             NaN
# 3    Here is my response based on the information...             NaN
# 4    Based on the information provided in the art...             NaN
# 6    Based on the information provided in the art...             NaN
#
#                                           NER_Pass_1  \
# 0  [(boston, 'GPE'), (monday, 'DATE'), (puerto ri...
# 2  [(sandoval, 'PERSON'), (first year, 'DATE'), (...
# 3  [(dan, 'PERSON'), (jerry pothier, 'PERSON'), (...
# 4  [(hillgarth, 'PERSON'), (boston, 'GPE'), (oxfo...
# 6  [(dudley macdougall, 'PERSON'), (chism, 'PERSO...
#
#                                    NER_Pass_1_Sorted NER_Pass_1_Coordinates  \
# 0  [(tsarnaev, 'ORG'), (tsarnaev, 'ORG'), (boston...                    NaN
# 2  [(sox, 'ORG'), (sox, 'ORG'), (sox, 'ORG'), (th...                    NaN
# 3  [(boston, 'GPE'), (maine, 'GPE'), (maine, 'GPE...                    NaN
# 4  [(the boston redevelopment authority, 'ORG'), ...                    NaN
# 6  [(danvers high school, 'ORG'), (bridgewater st...                    NaN
#
#                                       NER_prediction  \
# 0  [(Boston, 'GPE'), (Massachusetts, 'GPE'), (1, ...
# 2  [(Boston, 'GPE'), (Massachusetts, 'GPE'), (Fen...
# 3  [(1, 'CARDINAL'), (Boston, 'GPE'), (Jerry Poth...
# 4  [(Boston, 'GPE'), (Massachusetts, 'GPE'), (1, ...
# 6  [(Danvers, 'GPE'), (Massachusetts, 'GPE'), (1,...
#
#                                           NER_Sorted  ...  \
# 0  [('the First Circuit Appeals Court', 'ORG'), (...  ...
# 2  [('Fenway Park', 'FAC'), ('Fenway Park', 'FAC'...  ...
# 3  [('Marines', 'ORG'), ('Pearl Harbor', 'LOC'), ...  ...
# 4  [('the Prudential Center', 'FAC'), ('The Prude...  ...
# 6  [('Danvers High School', 'FAC'), ('Bridgewater...  ...
#
#                                                  hl2   author  \
# 0  puerto rico case suggests bomber can argue mar...  unknown
# 2  prospects devers, chavis still too far away to...  unknown
# 3                                            unknown  unknown
# 4                                            unknown  unknown
# 6                                            unknown  unknown
#
#                                                 lede    pub_date  \
# 0  in a decision that could provide a framework w...  2015-12-08
# 2  pablo sandoval's defense at third improved aft...  2015-12-08
# 3  jerry pothier was a medford guy. he was 18 yea...  2015-12-08
# 4  in his long quest to redevelop the harbor gara...  2015-12-08
# 6  dr. richard dudley testified monday that phili...  2015-12-08
#
#                                       indexing_terms  year  \
# 0  {'legal': [{'className': 'Criminal Law & Proce...  2015
# 2  {'subject': [{'score': '90', 'classCode': 'STX...  2015
# 3  {'subject': [{'score': '90', 'classCode': 'ST0...  2015
# 4  {'legal': [{'className': 'Transportation Law',...  2015
# 6  {'legal': [{'className': 'Criminal Law & Proce...  2015
#
#   actual_body_word_count                                       body_cleaned  \
# 0                    975  cases claim potential jurors inundated news me...
# 2                    586  sandoval ' first year boston calamitous every ...
# 3                    543  dad one guys ' talk much war , son dan said . ...
# 4                    807  bigger project , dig , says . means loss incom...
# 6                    657  caused difficulties ' caused , dr. dudley ? ma...
#
#     longitude    latitude
# 0 -71.0588801  42.3600825
# 2 -71.0972178  42.3466764
# 3 -71.0588801  42.3600825
# 4 -71.0817427  42.3470567
# 6 -70.9313851  42.5821203
#
# [5 rows x 25 columns]

# %%
'''
# Function to get tract ID using coordinates
def get_tract_id(lat, lon):
    url = f"https://geocoding.geo.census.gov/geocoder/geographies/coordinates?x={lat}&y={lon}&benchmark=Public_AR_Current&vintage=Census2010_Current&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        tract = data['result']['geographies'].get('Census Tracts', [])
        if tract: 
            return tract[0].get('TRACT', 'No TRACT found')
    return "No TRACT found"
   
'''

# %%
# Function to get tracts using coordinates
def get_tract_id(lat, lon):
    url = f"https://geocoding.geo.census.gov/geocoder/geographies/coordinates?x={lat}&y={lon}&benchmark=Public_AR_Current&vintage=Census2010_Current&format=json"
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            try:
                census_tracts = data['result']['geographies'].get('Census Tracts', [])
                if census_tracts:
                    return census_tracts[0].get('TRACT', 'No TRACT found')
                else:
                    return 'No Census Tracts found'
            except (KeyError, IndexError):
                print(f"Parsing error: {data}")
                return None
        else:
            print(f"Request failed with status code: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Request exception: {e}")
        return None

# %%
# Applying function to obtain tract ids
def update_tract_ids(df):
     
    # Initializing 'tract_2010' column
    df['tract_2010'] = None
    
    # Iterating through each row 
    for index, row in df.iterrows():
        lat, lon = row['latitude'], row['longitude']
        if pd.notna(lat) and pd.notna(lon):
            tract_id = get_tract_id(lon, lat)
            df.at[index, 'tract_2010'] = tract_id
        
        else:
            df.at[index, 'tract_2010'] = 'Invalid coordinates'
    
    return df

# %%
# Updating the DataFrame with tracts 
updated_bostonGlobe_2015 = update_tract_ids(bostonGlobe_2015)

# %%
# Investigating dataframe
updated_bostonGlobe_2015
# Out:
#       Unnamed: 0                                              hl1_x  \
# 0              0                     ruling may aid tsarnaev appeal
# 2              2                                   sandoval the one
# 3              3                            long life long on deeds
# 4              4  the developer v. the penguins (and their ceo) ...
# 6              6                chism expressed remorse expert says
# ...          ...                                                ...
# 4511        4511        in interview be clear about follow up plans
# 4512        4512  when off the court he likes to slow down and t...
# 4516        4516                                   spirit of giving
# 4517        4517   on walls and behind scenes women moved art world
# 4520        4520                      the ultimate quick pick me up
#
#                                                    body  \
# 0     both cases claim that the potential jurors wer...
# 2     but sandoval first year in boston was calamito...
# 3     my dad was one of those guys who didn talk muc...
# 4     the bigger the project the more you have to di...
# 6     caused the difficulties that he caused dr. dud...
# ...                                                 ...
# 4511  a. business etiquette is vital for companies a...
# 4512  favorite vacation spot turks and caicos. the w...
# 4516  at left spirited bostonian committee members m...
# 4517  echelman has worldwide following. she deserves...
# 4520  vernillet says that business travelers and fin...
#
#                                        llama_prediction Explicit_Pass_1  \
# 0       Based on the article provided, I would guess...             NaN
# 2       Based on the information provided in the art...             NaN
# 3       Here is my response based on the information...             NaN
# 4       Based on the information provided in the art...             NaN
# 6       Based on the information provided in the art...             NaN
# ...                                                 ...             ...
# 4511    Based on the information provided in the art...             NaN
# 4512    Based on the information provided in the art...             NaN
# 4516    Based on the information provided in the art...             NaN
# 4517    1.Y - The article is talking about Boston, s...             NaN
# 4520    1. Y - The article is talking about a specif...             NaN
#
#                                              NER_Pass_1  \
# 0     [(boston, 'GPE'), (monday, 'DATE'), (puerto ri...
# 2     [(sandoval, 'PERSON'), (first year, 'DATE'), (...
# 3     [(dan, 'PERSON'), (jerry pothier, 'PERSON'), (...
# 4     [(hillgarth, 'PERSON'), (boston, 'GPE'), (oxfo...
# 6     [(dudley macdougall, 'PERSON'), (chism, 'PERSO...
# ...                                                 ...
# 4511  [(glassdoor, 'ORG'), (six hours, 'TIME'), (tod...
# 4512  [(one, 'CARDINAL'), (wisconsin, 'GPE'), (disne...
# 4516  [(bostonian, 'NORP'), (marcia doyle, 'PERSON')...
# 4517  [(echelman, 'PERSON'), (joan jonas, 'PERSON'),...
# 4520  [(vernillet, 'PERSON'), (boston, 'GPE'), (25 m...
#
#                                       NER_Pass_1_Sorted  \
# 0     [(tsarnaev, 'ORG'), (tsarnaev, 'ORG'), (boston...
# 2     [(sox, 'ORG'), (sox, 'ORG'), (sox, 'ORG'), (th...
# 3     [(boston, 'GPE'), (maine, 'GPE'), (maine, 'GPE...
# 4     [(the boston redevelopment authority, 'ORG'), ...
# 6     [(danvers high school, 'ORG'), (bridgewater st...
# ...                                                 ...
# 4511  [(glassdoor, 'ORG'), (keystone partners, 'ORG'...
# 4512  [(disney world, 'ORG'), (disneyland, 'ORG'), (...
# 4516               [(connolly, 'ORG'), (boston, 'GPE')]
# 4517  [(mit, 'ORG'), (the rose art museum, 'ORG'), (...
# 4520  [(hilton short hills, 'ORG'), (boston, 'GPE'),...
#
#      NER_Pass_1_Coordinates  \
# 0                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 6                       NaN
# ...                     ...
# 4511                    NaN
# 4512                    NaN
# 4516                    NaN
# 4517                    NaN
# 4520                    NaN
#
#                                          NER_prediction  \
# 0     [(Boston, 'GPE'), (Massachusetts, 'GPE'), (1, ...
# 2     [(Boston, 'GPE'), (Massachusetts, 'GPE'), (Fen...
# 3     [(1, 'CARDINAL'), (Boston, 'GPE'), (Jerry Poth...
# 4     [(Boston, 'GPE'), (Massachusetts, 'GPE'), (1, ...
# 6     [(Danvers, 'GPE'), (Massachusetts, 'GPE'), (1,...
# ...                                                 ...
# 4511  [(1, 'CARDINAL'), (Boston, 'GPE'), (Massachuse...
# 4512  [(Boston, 'GPE'), (Massachusetts, 'GPE'), (1, ...
# 4516  [(Boston, 'GPE'), (Massachusetts, 'GPE'), (1, ...
# 4517  [(Boston, 'GPE'), (New England, 'LOC'), (Bosto...
# 4520  [(1, 'CARDINAL'), (Boston, 'GPE'), (the Financ...
#
#                                              NER_Sorted  ...   author  \
# 0     [('the First Circuit Appeals Court', 'ORG'), (...  ...  unknown
# 2     [('Fenway Park', 'FAC'), ('Fenway Park', 'FAC'...  ...  unknown
# 3     [('Marines', 'ORG'), ('Pearl Harbor', 'LOC'), ...  ...  unknown
# 4     [('the Prudential Center', 'FAC'), ('The Prude...  ...  unknown
# 6     [('Danvers High School', 'FAC'), ('Bridgewater...  ...  unknown
# ...                                                 ...  ...      ...
# 4511  [('Keystone Partners', 'ORG'), ('Keystone Part...  ...  unknown
# 4512  [('Beacon Hill', 'LOC'), ('Beacon Hill', 'LOC'...  ...  unknown
# 4516  [('the "Rattlesnake Bar Grill"', 'FAC'), ('the...  ...  unknown
# 4517  [('the Rose Art Museum', 'FAC'), ('The Wadswor...  ...  unknown
# 4520  [('Naples Grande Beach Resort Spa', 'FAC'), ('...  ...  unknown
#
#                                                    lede    pub_date  \
# 0     in a decision that could provide a framework w...  2015-12-08
# 2     pablo sandoval's defense at third improved aft...  2015-12-08
# 3     jerry pothier was a medford guy. he was 18 yea...  2015-12-08
# 4     in his long quest to redevelop the harbor gara...  2015-12-08
# 6     dr. richard dudley testified monday that phili...  2015-12-08
# ...                                                 ...         ...
# 4511  q. after 15 years in europe, i'm interviewing ...  2015-12-27
# 4512  evan turner of the celtics took a selfie in mi...  2015-12-27
# 4516  at left, spirited bostonian committee members ...  2015-12-27
# 4517  clockwise from top: janet echelman's "as if it...  2015-12-27
# 4520  whether it's business or pleasure travel, more...  2015-12-27
#
#                                          indexing_terms  year  \
# 0     {'legal': [{'className': 'Criminal Law & Proce...  2015
# 2     {'subject': [{'score': '90', 'classCode': 'STX...  2015
# 3     {'subject': [{'score': '90', 'classCode': 'ST0...  2015
# 4     {'legal': [{'className': 'Transportation Law',...  2015
# 6     {'legal': [{'className': 'Criminal Law & Proce...  2015
# ...                                                 ...   ...
# 4511  {'subject': [{'score': '90', 'classCode': 'ST0...  2015
# 4512  {'subject': [{'score': '90', 'classCode': 'ST0...  2015
# 4516  {'subject': [{'score': '90', 'classCode': 'ST0...  2015
# 4517  {'legal': [{'className': 'Education Law', 'cla...  2015
# 4520  {'subject': [{'score': '78', 'classCode': 'ST0...  2015
#
#      actual_body_word_count  \
# 0                       975
# 2                       586
# 3                       543
# 4                       807
# 6                       657
# ...                     ...
# 4511                    207
# 4512                    209
# 4516                     94
# 4517                    651
# 4520                    385
#
#                                            body_cleaned   longitude  \
# 0     cases claim potential jurors inundated news me... -71.0588801
# 2     sandoval ' first year boston calamitous every ... -71.0972178
# 3     dad one guys ' talk much war , son dan said . ... -71.0588801
# 4     bigger project , dig , says . means loss incom... -71.0817427
# 6     caused difficulties ' caused , dr. dudley ? ma... -70.9313851
# ...                                                 ...         ...
# 4511  a. business etiquette vital companies individu... -71.0571176
# 4512  favorite vacation spot ? turks caicos . water ... -71.0693900
# 4516  left , spirited bostonian committee members ma... -71.0719348
# 4517  echelman worldwide following . deserves attent... -71.2624995
# 4520  vernillet says business travelers financial di... -81.7948103
#
#         latitude tract_2010
# 0     42.3600825     030300
# 2     42.3466764     010203
# 3     42.3600825     030300
# 4     42.3470567     010600
# 6     42.5821203     211300
# ...          ...        ...
# 4511  42.3530449     070101
# 4512  42.3561948     981700
# 4516  42.3513496     010702
# 4517  42.3656832     368400
# 4520  26.1420358     000102
#
# [2749 rows x 26 columns]

# %%
# Calculating the number of times "No tract found" appears in the updated tract column
no_tract_found_count = (updated_bostonGlobe_2015['tract_2010'] == 'No Census Tracts found').sum()
no_tract_found_count
# Out:
# 8

# %%
# Removing rows with "No Census Tracts found" 
updated_bostonGlobe_2015.drop(updated_bostonGlobe_2015[updated_bostonGlobe_2015['tract_2010'] == 'No Census Tracts found'].index, inplace=True)

# %%
# Saving the updated DataFrame to a new CSV file
updated_bostonGlobe_2015.to_csv('updated_bostonGlobe_2015.csv', index=False)

# %%
updated_bostonGlobe_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2741 entries, 0 to 4520
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2741 non-null   int64
#  1   hl1_x                   2741 non-null   object
#  2   body                    2741 non-null   object
#  3   llama_prediction        2741 non-null   object
#  4   Explicit_Pass_1         0 non-null      object
#  5   NER_Pass_1              2741 non-null   object
#  6   NER_Pass_1_Sorted       2741 non-null   object
#  7   NER_Pass_1_Coordinates  0 non-null      object
#  8   NER_prediction          2741 non-null   object
#  9   NER_Sorted              2741 non-null   object
#  10  NER_Sorted_Coordinates  2741 non-null   object
#  11  Tracts                  2741 non-null   object
#  12  position_section        2741 non-null   object
#  13  position_subsection     2741 non-null   object
#  14  hl1_y                   2741 non-null   object
#  15  hl2                     2741 non-null   object
#  16  author                  2741 non-null   object
#  17  lede                    2741 non-null   object
#  18  pub_date                2741 non-null   object
#  19  indexing_terms          2741 non-null   object
#  20  year                    2741 non-null   int64
#  21  actual_body_word_count  2741 non-null   int64
#  22  body_cleaned            2741 non-null   object
#  23  longitude               2741 non-null   float64
#  24  latitude                2741 non-null   float64
#  25  tract_2010              2741 non-null   object
# dtypes: float64(2), int64(3), object(21)
# memory usage: 578.2+ KB
