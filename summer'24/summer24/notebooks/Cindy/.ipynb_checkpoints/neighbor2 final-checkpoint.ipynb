# %%
# load csv files into dataframes 

import pandas as pd

# Loading Boston Globe dataset 
data1_b = pd.read_csv('/Users/rachelgupta/Desktop/NAACP - PIT NE/pitne-bias-in-media/summer24/Data/Combined_Datasets_3/2010/updated_bostonGlobe_2010.csv')

# census data, using 2010
data2_c = pd.read_csv('/Users/rachelgupta/Desktop/NAACP - PIT NE/pitne-bias-in-media/summer24/Data/Combined_Datasets_3/2010_N.csv')

#dropping rows with 'No TRACTSfound'
data1_b.dropna(subset=['Tracts'], inplace=True)
data1_b.head()
# Out:
#    Unnamed: 0                                     hl1_x  \
# 0           0    cerezyme alternative gets fda approval
# 1           2                           flawed calculus
# 2           3                            advantage kids
# 3           6                  delahunt out field opens
# 4           7  wakefield boy dies after falling in pond
#
#                                                 body  \
# 0  washington the food and drug administration ha...
# 1  in 1993 amy bishop and her husband james ander...
# 2  all these kids are at risk of being involved i...
# 3  democratic candidates include state senator ro...
# 4  wakefield police responded about 11 30 a.m. to...
#
#                                     llama_prediction  Explicit_Pass_1  \
# 0    Here is my response based on the information...              NaN
# 1    Based on the information provided in the art...              NaN
# 2    Here is my assessment of the article's locat...              NaN
# 3    Based on the information provided in the art...              NaN
# 4    Based on the information provided in the art...              NaN
#
#                                           NER_Pass_1  \
# 0  [(washington, 'GPE'), (less than one, 'CARDINA...
# 1  [(1993, 'DATE'), (amy bishop, 'PERSON'), (jame...
# 2  [(williams, 'PERSON'), (tayleece, 'PERSON'), (...
# 3  [(democratic, 'NORP'), (robert a. leary, 'PERS...
# 4  [(wakefield, 'GPE'), (about 11 30 a.m., 'TIME'...
#
#                                    NER_Pass_1_Sorted  NER_Pass_1_Coordinates  \
# 0  [(washington, 'GPE'), (the united states, 'GPE...                     NaN
# 1  [(children hospital, 'ORG'), (globe, 'ORG'), (...                     NaN
# 2  [(the boston foundation, 'ORG'), (muriel s. sn...                     NaN
# 3  [(the state democratic party, 'ORG'), (the qui...                     NaN
# 4  [(melrose wakefield hospital, 'ORG'), (wakefie...                     NaN
#
#                                       NER_prediction  \
# 0  [(1, 'CARDINAL'), (Boston, 'GPE'), (Massachuse...
# 1  [(Boston, 'GPE'), (Massachusetts, 'GPE'), (Bos...
# 2  [(1, 'CARDINAL'), (Boston, 'GPE'), (South Bost...
# 3  [(the 10th Congressional District, 'LOC'), (Ma...
# 4  [(Wakefield, 'GPE'), (Massachusetts, 'GPE'), (...
#
#                                           NER_Sorted  ...            author  \
# 0  [('Genzyme Corp.', 'ORG'), ('Genzyme Corp.', '...  ...  Associated Press
# 1  [('ATF', 'ORG'), ('Childrens Hospital', 'ORG')...  ...      Kevin Cullen
# 2  [('the Sportsmen Club', 'FAC'), ('The Sportsme...  ...           unknown
# 3  [('the 10th Congressional District', 'LOC'), (...  ...           unknown
# 4  [('Lake Street', 'FAC'), ('Lake Street', 'FAC'...  ...           unknown
#
#                                                 lede    pub_date  \
# 0  washington - the food and drug administration ...  2010-02-27
# 1  when it comes to amy bishop, the harvard-train...  2010-02-16
# 2  in tennis, how you play can matter as much as ...  2010-07-20
# 3  quincy - us representative william d. delahunt...  2010-03-06
# 4  a 2-year-old boy drowned in a man-made pond in...  2010-04-27
#
#                                       indexing_terms  year  \
# 0  {'subject': [{'score': '91', 'classCode': 'ST0...  2010
# 1  {'subject': [{'score': '90', 'classCode': 'STX...  2010
# 2  {'subject': [{'score': '90', 'classCode': 'STX...  2010
# 3  {'subject': [{'score': '91', 'classCode': 'ST0...  2010
# 4  {'subject': [{'score': '90', 'classCode': 'STX...  2010
#
#   actual_body_word_count                                       body_cleaned  \
# 0                     91  washington food drug administration approved n...
# 1                    555  1993 , amy bishop husband , james anderson , q...
# 2                    604  kids risk involved gang- related activity , sa...
# 3                    811  democratic candidates include state senator ro...
# 4                    178  wakefield police responded 11 : 30 a. m. home ...
#
#    longitude   latitude tract_2010
# 0 -71.118563  42.362780        803
# 1 -71.058880  42.360082      30300
# 2 -71.058880  42.360082      30300
# 3 -71.382437  42.407211     365100
# 4 -71.163692  42.344704        402
#
# [5 rows x 26 columns]

# %%
# To examine full dataset without truncation 
pd.set_option('display.max_rows', None)  # None means display all rows
pd.set_option('display.max_columns', None)  # None means display all columns

# %%
#index names for boston globe data
data1_b.columns
# Out:
# Index(['Unnamed: 0', 'hl1_x', 'body', 'llama_prediction', 'Explicit_Pass_1',
#        'NER_Pass_1', 'NER_Pass_1_Sorted', 'NER_Pass_1_Coordinates',
#        'NER_prediction', 'NER_Sorted', 'NER_Sorted_Coordinates', 'Tracts',
#        'position_section', 'position_subsection', 'hl1_y', 'hl2', 'author',
#        'lede', 'pub_date', 'indexing_terms', 'year', 'actual_body_word_count',
#        'body_cleaned', 'longitude', 'latitude', 'tract_2010'],
#       dtype='object')

# %%
#index names for census data
data2_c.columns
# Out:
# Index(['geoid', 'cr_geoid', 'name', 'original_id', 'pop100', 'hu100',
#        'state_place_fips'],
#       dtype='object')

# %%
#processing boston globe data, the tracts are an array, making it into a list of strings
 
# cleaning function
def clean_tract(tract):
    return tract.strip("[]' ")

# Apply the function to the 'tract' column, replacing old column with this new info
data1_b['Tracts'] = data1_b['Tracts'].apply(clean_tract)

# Print the DataFrame to verify
#print(data1_b[['Tracts']].head())

data1_b.head()
# Out:
#    Unnamed: 0                                     hl1_x  \
# 0           0    cerezyme alternative gets fda approval
# 1           2                           flawed calculus
# 2           3                            advantage kids
# 3           6                  delahunt out field opens
# 4           7  wakefield boy dies after falling in pond
#
#                                                 body  \
# 0  washington the food and drug administration ha...
# 1  in 1993 amy bishop and her husband james ander...
# 2  all these kids are at risk of being involved i...
# 3  democratic candidates include state senator ro...
# 4  wakefield police responded about 11 30 a.m. to...
#
#                                     llama_prediction  Explicit_Pass_1  \
# 0    Here is my response based on the information...              NaN
# 1    Based on the information provided in the art...              NaN
# 2    Here is my assessment of the article's locat...              NaN
# 3    Based on the information provided in the art...              NaN
# 4    Based on the information provided in the art...              NaN
#
#                                           NER_Pass_1  \
# 0  [(washington, 'GPE'), (less than one, 'CARDINA...
# 1  [(1993, 'DATE'), (amy bishop, 'PERSON'), (jame...
# 2  [(williams, 'PERSON'), (tayleece, 'PERSON'), (...
# 3  [(democratic, 'NORP'), (robert a. leary, 'PERS...
# 4  [(wakefield, 'GPE'), (about 11 30 a.m., 'TIME'...
#
#                                    NER_Pass_1_Sorted  NER_Pass_1_Coordinates  \
# 0  [(washington, 'GPE'), (the united states, 'GPE...                     NaN
# 1  [(children hospital, 'ORG'), (globe, 'ORG'), (...                     NaN
# 2  [(the boston foundation, 'ORG'), (muriel s. sn...                     NaN
# 3  [(the state democratic party, 'ORG'), (the qui...                     NaN
# 4  [(melrose wakefield hospital, 'ORG'), (wakefie...                     NaN
#
#                                       NER_prediction  \
# 0  [(1, 'CARDINAL'), (Boston, 'GPE'), (Massachuse...
# 1  [(Boston, 'GPE'), (Massachusetts, 'GPE'), (Bos...
# 2  [(1, 'CARDINAL'), (Boston, 'GPE'), (South Bost...
# 3  [(the 10th Congressional District, 'LOC'), (Ma...
# 4  [(Wakefield, 'GPE'), (Massachusetts, 'GPE'), (...
#
#                                           NER_Sorted  \
# 0  [('Genzyme Corp.', 'ORG'), ('Genzyme Corp.', '...
# 1  [('ATF', 'ORG'), ('Childrens Hospital', 'ORG')...
# 2  [('the Sportsmen Club', 'FAC'), ('The Sportsme...
# 3  [('the 10th Congressional District', 'LOC'), (...
# 4  [('Lake Street', 'FAC'), ('Lake Street', 'FAC'...
#
#       NER_Sorted_Coordinates  Tracts position_section position_subsection  \
# 0  [-71.1185629, 42.3627796]  000806         BUSINESS             unknown
# 1  [-71.0588801, 42.3600825]  030302             NEWS               Metro
# 2  [-71.0588801, 42.3600825]  030302             NEWS               Metro
# 3  [-71.3824374, 42.4072107]  365100             NEWS               Metro
# 4  [-71.1636923, 42.3447035]  000402             NEWS               Metro
#
#                                       hl1_y  \
# 0    cerezyme alternative gets fda approval
# 1                           flawed calculus
# 2                            advantage kids
# 3                  delahunt out field opens
# 4  wakefield boy dies after falling in pond
#
#                                                  hl2            author  \
# 0                                            unknown  Associated Press
# 1                                            unknown      Kevin Cullen
# 2  with tennis, hub police get youths off city's ...           unknown
# 3  republican candidates position themselves for ...           unknown
# 4                 wandered away as mother did chores           unknown
#
#                                                 lede    pub_date  \
# 0  washington - the food and drug administration ...  2010-02-27
# 1  when it comes to amy bishop, the harvard-train...  2010-02-16
# 2  in tennis, how you play can matter as much as ...  2010-07-20
# 3  quincy - us representative william d. delahunt...  2010-03-06
# 4  a 2-year-old boy drowned in a man-made pond in...  2010-04-27
#
#                                       indexing_terms  year  \
# 0  {'subject': [{'score': '91', 'classCode': 'ST0...  2010
# 1  {'subject': [{'score': '90', 'classCode': 'STX...  2010
# 2  {'subject': [{'score': '90', 'classCode': 'STX...  2010
# 3  {'subject': [{'score': '91', 'classCode': 'ST0...  2010
# 4  {'subject': [{'score': '90', 'classCode': 'STX...  2010
#
#    actual_body_word_count                                       body_cleaned  \
# 0                      91  washington food drug administration approved n...
# 1                     555  1993 , amy bishop husband , james anderson , q...
# 2                     604  kids risk involved gang- related activity , sa...
# 3                     811  democratic candidates include state senator ro...
# 4                     178  wakefield police responded 11 : 30 a. m. home ...
#
#    longitude   latitude  tract_2010
# 0 -71.118563  42.362780         803
# 1 -71.058880  42.360082       30300
# 2 -71.058880  42.360082       30300
# 3 -71.382437  42.407211      365100
# 4 -71.163692  42.344704         402

# %%
#processing a subset of Census data, isolating location and geoid

d2_subset = data2_c[['geoid', 'name']]
d2_subset
d2_subset.dtypes   
# geoid is an int64, changinging from int64 to str

def int_to_string(num):
    "int to str"
    return str(num)

def get_list(subset, label):
    "get list"
    string_list = []
    for x in subset[label]:
        x= int_to_string(x)
        string_list.append(x)
    return string_list

string_geoid = get_list(d2_subset,'geoid')
string_geoid   #string list of geoid

# replace this list with column in Census
data2_c['geoid'] = string_geoid

data2_c.dtypes  # checks that type for geoid is a string(aka object)
# Out:
# geoid               object
# cr_geoid             int64
# name                object
# original_id          int64
# pop100               int64
# hu100                int64
# state_place_fips     int64
# dtype: object

# %%
#Process geoid colum in census dataset, for each string do an approprioate slicing (5:11)

def calculate_tract(df):
    # Assuming the column name is 'column_name' and the DataFrame is 'df'
    new_list = []
    for x in df:
        sliced_string = x[5:11]  # Change the slice range as per your requirement
        new_list.append(sliced_string)
    return new_list


calc_t= calculate_tract(string_geoid)

#  add calculatedtract column to oG data set for census  # works 
data2_c['Calculated_Tract'] = calc_t
data2_c.head()    # type for calculated tract is object
# Out:
#              geoid  cr_geoid         name  original_id  pop100  hu100  \
# 0  250250703001010       178  Bay Village           33      49      5
# 1  250250703001011       178  Bay Village           33     201    143
# 2  250250703001012       178  Bay Village           33     324    235
# 3  250250703001013       178  Bay Village           33       0      0
# 4  250250703001014       178  Bay Village           33       5      5
#
#    state_place_fips Calculated_Tract
# 0           2507000           070300
# 1           2507000           070300
# 2           2507000           070300
# 3           2507000           070300
# 4           2507000           070300

# %%
data2_c.dtypes
# Out:
# geoid               object
# cr_geoid             int64
# name                object
# original_id          int64
# pop100               int64
# hu100                int64
# state_place_fips     int64
# Calculated_Tract    object
# dtype: object

# %%
# Convert the 'Calculated_Tract' column to numeric, handling errors
data2_c['Calculated_Tract'] = pd.to_numeric(data2_c['Calculated_Tract'], errors='coerce')

# %%
data1_b.columns
# Out:
# Index(['Unnamed: 0', 'hl1_x', 'body', 'llama_prediction', 'Explicit_Pass_1',
#        'NER_Pass_1', 'NER_Pass_1_Sorted', 'NER_Pass_1_Coordinates',
#        'NER_prediction', 'NER_Sorted', 'NER_Sorted_Coordinates', 'Tracts',
#        'position_section', 'position_subsection', 'hl1_y', 'hl2', 'author',
#        'lede', 'pub_date', 'indexing_terms', 'year', 'actual_body_word_count',
#        'body_cleaned', 'longitude', 'latitude', 'tract_2010'],
#       dtype='object')

# %%
new_census_subset =  data2_c[['Calculated_Tract', 'name']]

# this new dataset wil be merged with other census on Tract and Calculated Tract





merged_data = data1_b.merge(new_census_subset[['Calculated_Tract','name']] , left_on='tract_2010', right_on= "Calculated_Tract", how='inner')


merged_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yt/yy9gqhbd1f12h4vcpqpnhq400000gn/T/ipykernel_5431/4071598418.py in <module>
#      10
#      11
# ---> 12 merged_data
#      13
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/opt/anaconda3/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _repr_html_(self)
#    1045                 decimal=".",
#    1046             )
# -> 1047             return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1048         else:
#    1049             return None
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1027             render_links=render_links,
#    1028         )
# -> 1029         string = html_formatter.to_string()
#    1030         return save_to_buffer(string, buf=buf, encoding=encoding)
#    1031
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/html.py in to_string(self)
#      70
#      71     def to_string(self) -> str:
# ---> 72         lines = self.render()
#      73         if any(isinstance(x, str) for x in lines):
#      74             lines = [str(x) for x in lines]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/html.py in render(self)
#     619         self.write("<div>")
#     620         self.write_style()
# --> 621         super().render()
#     622         self.write("</div>")
#     623         return self.elements
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/html.py in render(self)
#      76
#      77     def render(self) -> list[str]:
# ---> 78         self._write_table()
#      79
#      80         if self.should_show_dimensions:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     246             self._write_header(indent + self.indent_delta)
#     247
# --> 248         self._write_body(indent + self.indent_delta)
#     249
#     250         self.write("</table>", indent)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     393     def _write_body(self, indent: int) -> None:
#     394         self.write("<tbody>", indent)
# --> 395         fmt_values = self._get_formatted_values()
#     396
#     397         # write values
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/html.py in _get_formatted_values(self)
#     583
#     584     def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 585         return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#     586
#     587     def _get_columns_formatted_values(self) -> list[str]:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/html.py in <dictcomp>(.0)
#     583
#     584     def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 585         return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#     586
#     587     def _get_columns_formatted_values(self) -> list[str]:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in format_col(self, i)
#     816         frame = self.tr_frame
#     817         formatter = self._get_formatter(i)
# --> 818         return format_array(
#     819             frame.iloc[:, i]._values,
#     820             formatter,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1238     )
#    1239
# -> 1240     return fmt_obj.get_result()
#    1241
#    1242
#
# KeyboardInterrupt:

# %%
duplicates = merged_data["Calculated_Tract"].duplicated().sum()
duplicates
# Out:
# 54702

# %%
#Figuring Out how many articles appear in each neighborhood 

import pandas as pd

# Assuming the merged data is stored in a variable called 'merged_data'
frequencyy = merged_data['name'].value_counts().reset_index()

# Rename the columns in the dataframe
frequencyy.columns = ['Name', 'Count']

# Display the dataframe
frequencyy
# Out:
#                        Name  Count
# 0                    Fenway  13334
# 1                Dorchester   5950
# 2                  Back Bay   4804
# 3                   Roxbury   4345
# 4               East Boston   4286
# 5                  Brighton   3935
# 6             Jamaica Plain   3305
# 7               Charlestown   2366
# 8                 South End   1398
# 9               Beacon Hill   1346
# 10                 Longwood   1317
# 11                 Mattapan   1274
# 12                Hyde Park   1229
# 13               Roslindale   1091
# 14             West Roxbury   1036
# 15                 West End    815
# 16             South Boston    812
# 17             Mission Hill    687
# 18                North End    605
# 19                  Allston    417
# 20           Harbor Islands    230
# 21  South Boston Waterfront    144
# 22                 Downtown    101
# 23                Chinatown      9

# %%
import matplotlib.pyplot as plt

# Define the variables
locations = frequencyy['Name']  
counts = frequencyy['Count']  


# Create the bar plot to visualize the articles perneighborhood
plt.figure(figsize=(12, 8))
plt.bar(locations, counts)
plt.title('Frequency of Articles per Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Article Count')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# Rachel's merged race document, for race per neighborhood

# loadd csv files
data3_r = pd.read_csv('Current_Data_Being_Used/redistricting_data_tract20_nbhd_hhpopsize_ab-1.csv')

#load colum names, # tract20_nbhd  for neighborhood name
data3_r.columns

#data3_r
# Out:
# Index(['tract20_nbhd', 'P0020001', 'P0020005', 'P0020006', 'P0020002',
#        'P002aapi', 'P002others', 'P0040001', 'P0040005', 'P0040006',
#        'P0040002', 'P004aapi', 'P004others', 'P00x0001', 'P00x0005',
#        'P00x0006', 'P00x0002', 'P00xaapi', 'P00xothers', 'hhpop', 'P0050001',
#        'P0050002', 'P0050003', 'P0050004', 'P0050005', 'P0050006', 'P0050007',
#        'P0050008', 'P0050009', 'P0050010', 'H0010001', 'H0010002', 'H0010003',
#        'hhsize'],
#       dtype='object')

# %%
#  Getting rid of iirelevant columns from race document

race = data3_r.drop(columns = ['P0040001', 'P0040005', 'P0040006',
       'P0040002', 'P004aapi', 'P004others', 'P00x0001', 'P00x0005',
       'P00x0006', 'P00x0002', 'P00xaapi', 'P00xothers', 'hhpop', 'P0050001',
       'P0050002', 'P0050003', 'P0050004', 'P0050005', 'P0050006', 'P0050007',
       'P0050008', 'P0050009', 'P0050010', 'H0010001', 'H0010002', 'H0010003',
       'hhsize'])

race.rename(columns={"P0020005": "White alone", 
                            "P0020006": "Black or African American alone", 
                            "P0020002": "Hispanic or Latino", 
                            "P0020008": "Asian alone", 
                            "P0020007": "American Indian and Alaska Native alone", 
                            "P0020009": "Native Hawaiian and Other Pacific Islander alone", 
                            "P0020010": "Some Other Race alone", 
                            "P002aapi":"Asian, Native Hawaiian and Pacific Islander",
                            "P002others":"Other Races or Multiple Races",
                            "P0020011":"Population of two or more races",
                            "P0020001":"Total",
                            "tract20_nbhd":"Neighborhood"}, inplace=True)

 

race = race.drop(0)

# %%
# merge race w merged document containing neighborhoods

all_data = merged_data.merge(race,left_on='name', right_on='Neighborhood', how='left')
all_data
# Out:
#        Unnamed: 0                                              hl1_x  \
# 0               4  davis right to ask for da probe of police in r...
# 1               4  davis right to ask for da probe of police in r...
# 2               4  davis right to ask for da probe of police in r...
# 3               4  davis right to ask for da probe of police in r...
# 4               4  davis right to ask for da probe of police in r...
# ...           ...                                                ...
# 54831        4662                                         folding up
# 54832        4662                                         folding up
# 54833        4662                                         folding up
# 54834        4662                                         folding up
# 54835        4662                                         folding up
#
#                                                     body llama_prediction  \
# 0      cellphone video taken by student at roxbury co...              NaN
# 1      cellphone video taken by student at roxbury co...              NaN
# 2      cellphone video taken by student at roxbury co...              NaN
# 3      cellphone video taken by student at roxbury co...              NaN
# 4      cellphone video taken by student at roxbury co...              NaN
# ...                                                  ...              ...
# 54831  the holtons are not alone in questioning wheth...              NaN
# 54832  the holtons are not alone in questioning wheth...              NaN
# 54833  the holtons are not alone in questioning wheth...              NaN
# 54834  the holtons are not alone in questioning wheth...              NaN
# 54835  the holtons are not alone in questioning wheth...              NaN
#
#                               Explicit_Pass_1  \
# 0      ['roxbury', [-71.0834538, 42.3286377]]
# 1      ['roxbury', [-71.0834538, 42.3286377]]
# 2      ['roxbury', [-71.0834538, 42.3286377]]
# 3      ['roxbury', [-71.0834538, 42.3286377]]
# 4      ['roxbury', [-71.0834538, 42.3286377]]
# ...                                       ...
# 54831                                     NaN
# 54832                                     NaN
# 54833                                     NaN
# 54834                                     NaN
# 54835                                     NaN
#
#                                               NER_Pass_1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 54831  [(holtons, 'PERSON'), (esdale, 'PERSON'), (wal...
# 54832  [(holtons, 'PERSON'), (esdale, 'PERSON'), (wal...
# 54833  [(holtons, 'PERSON'), (esdale, 'PERSON'), (wal...
# 54834  [(holtons, 'PERSON'), (esdale, 'PERSON'), (wal...
# 54835  [(holtons, 'PERSON'), (esdale, 'PERSON'), (wal...
#
#                                        NER_Pass_1_Sorted  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 54831  [(pinewood lodge, 'FAC'), (merrill associates ...
# 54832  [(pinewood lodge, 'FAC'), (merrill associates ...
# 54833  [(pinewood lodge, 'FAC'), (merrill associates ...
# 54834  [(pinewood lodge, 'FAC'), (merrill associates ...
# 54835  [(pinewood lodge, 'FAC'), (merrill associates ...
#
#           NER_Pass_1_Coordinates NER_prediction NER_Sorted  ...  \
# 0                            NaN            NaN         []  ...
# 1                            NaN            NaN         []  ...
# 2                            NaN            NaN         []  ...
# 3                            NaN            NaN         []  ...
# 4                            NaN            NaN         []  ...
# ...                          ...            ...        ...  ...
# 54831  [-71.1088121, 42.2676153]            NaN         []  ...
# 54832  [-71.1088121, 42.2676153]            NaN         []  ...
# 54833  [-71.1088121, 42.2676153]            NaN         []  ...
# 54834  [-71.1088121, 42.2676153]            NaN         []  ...
# 54835  [-71.1088121, 42.2676153]            NaN         []  ...
#
#                                             body_cleaned Calculated_Tract  \
# 0      cellphone video taken student roxbury communit...           081700
# 1      cellphone video taken student roxbury communit...           081700
# 2      cellphone video taken student roxbury communit...           081700
# 3      cellphone video taken student roxbury communit...           081700
# 4      cellphone video taken student roxbury communit...           081700
# ...                                                  ...              ...
# 54831  holtons alone questioning whether operating fa...           140400
# 54832  holtons alone questioning whether operating fa...           140400
# 54833  holtons alone questioning whether operating fa...           140400
# 54834  holtons alone questioning whether operating fa...           140400
# 54835  holtons alone questioning whether operating fa...           140400
#
#             name Neighborhood  Total White alone  \
# 0        Roxbury      Roxbury  54533        7137
# 1        Roxbury      Roxbury  54533        7137
# 2        Roxbury      Roxbury  54533        7137
# 3        Roxbury      Roxbury  54533        7137
# 4        Roxbury      Roxbury  54533        7137
# ...          ...          ...    ...         ...
# 54831  Hyde Park    Hyde Park  34172        7632
# 54832  Hyde Park    Hyde Park  34172        7632
# 54833   Mattapan     Mattapan  23840        1489
# 54834   Mattapan     Mattapan  23840        1489
# 54835   Mattapan     Mattapan  23840        1489
#
#       Black or African American alone Hispanic or Latino  \
# 0                               22624              16633
# 1                               22624              16633
# 2                               22624              16633
# 3                               22624              16633
# 4                               22624              16633
# ...                               ...                ...
# 54831                           15628               8319
# 54832                           15628               8319
# 54833                           16277               4083
# 54834                           16277               4083
# 54835                           16277               4083
#
#       Asian, Native Hawaiian and Pacific Islander  \
# 0                                            3222
# 1                                            3222
# 2                                            3222
# 3                                            3222
# 4                                            3222
# ...                                           ...
# 54831                                         736
# 54832                                         736
# 54833                                         491
# 54834                                         491
# 54835                                         491
#
#       Other Races or Multiple Races
# 0                              4917
# 1                              4917
# 2                              4917
# 3                              4917
# 4                              4917
# ...                             ...
# 54831                          1857
# 54832                          1857
# 54833                          1500
# 54834                          1500
# 54835                          1500
#
# [54836 rows x 32 columns]

# %%
# creating race df 
max_race_df = pd.DataFrame(race)

# dropping total column because it has the highest count
max_race1= max_race_df.drop(columns= ['Total'])
                        
#calculating highest race

max_race1.set_index("Neighborhood", inplace=True)
new_df_num = max_race1.apply(pd.to_numeric, errors='coerce')

# Identifying the highest race for each tract and adding a new column
max_race1["majority_race"] = new_df_num.idxmax(axis=1)

# Displaying the updated dataframe
max_race1.reset_index(inplace=True)
max_race1

#conjoin all
# Out:
#                Neighborhood White alone Black or African American alone  \
# 0                   Allston       12536                            1326
# 1                  Back Bay       13065                             690
# 2               Beacon Hill        7521                             252
# 3                  Brighton       32694                            2414
# 4               Charlestown       13626                             990
# 5                 Chinatown        1844                             254
# 6                Dorchester       27411                           42714
# 7                  Downtown        8730                             569
# 8               East Boston       15760                            1403
# 9                    Fenway       20350                            2333
# 10                Hyde Park        7632                           15628
# 11            Jamaica Plain       21463                            4511
# 12                 Longwood        3584                             329
# 13                 Mattapan        1489                           16277
# 14             Mission Hill        6635                            2427
# 15                North End        9306                             141
# 16               Roslindale       14014                            5784
# 17                  Roxbury        7137                           22624
# 18             South Boston       29139                            1529
# 19  South Boston Waterfront        4315                             160
# 20                South End       17362                            3259
# 21                 West End        4933                             338
# 22             West Roxbury       20918                            3312
#
#    Hispanic or Latino Asian, Native Hawaiian and Pacific Islander  \
# 0                3259                                        6271
# 1                1208                                        2410
# 2                 537                                         630
# 3                5376                                        8703
# 4                2075                                        1650
# 5                 451                                        3480
# 6               25285                                       13360
# 7                 967                                        3018
# 8               21700                                        1932
# 9                3565                                        9210
# 10               8319                                         736
# 11               8664                                        3042
# 12                486                                         612
# 13               4083                                         491
# 14               3341                                        4315
# 15                528                                         445
# 16               7255                                         987
# 17              16633                                        3222
# 18               3887                                        2077
# 19                316                                         482
# 20               3998                                        4875
# 21                613                                        1440
# 22               3567                                        2451
#
#    Other Races or Multiple Races                                majority_race
# 0                           1512                                  White alone
# 1                            817                                  White alone
# 2                            396                                  White alone
# 3                           2860                                  White alone
# 4                            779                                  White alone
# 5                            182  Asian, Native Hawaiian and Pacific Islander
# 6                          13421              Black or African American alone
# 7                            484                                  White alone
# 8                           2271                           Hispanic or Latino
# 9                           2035                                  White alone
# 10                          1857              Black or African American alone
# 11                          2335                                  White alone
# 12                           175                                  White alone
# 13                          1500              Black or African American alone
# 14                           800                                  White alone
# 15                           385                                  White alone
# 16                          1546                                  White alone
# 17                          4917              Black or African American alone
# 18                          1285                                  White alone
# 19                           306                                  White alone
# 20                          1410                                  White alone
# 21                           381                                  White alone
# 22                          1313                                  White alone

# %%
# merge race with final dataset

#finalized = all_data.merge(max_race1,left_on='name', right_on='Neighborhood', how='inner')

#finalized.columns

# %%
complete
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/yt/yy9gqhbd1f12h4vcpqpnhq400000gn/T/ipykernel_26988/1936507658.py in <module>
# ----> 1 complete
#
# NameError: name 'complete' is not defined

# %%
complete = merged_data.merge( max_race1,left_on='name', right_on='Neighborhood', how='inner' )

completefinal = complete.drop_duplicates(subset=['Unnamed: 0'])


complete.to_csv('2010complete.csv', index=False)

# %%
complete.to_csv('2010complete.csv', index=False)
