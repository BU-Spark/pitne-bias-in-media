# %%
# Main imports
import pandas as pd
import numpy as np
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import os, sys
import seaborn as sns
from tqdm import tqdm
from copy import deepcopy
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
tqdm.pandas()
# Out:
# [nltk_data] Downloading package punkt to /Users/iranjan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
bglobe_data = pd.read_csv('/Users/iranjan/Projects/dd4g-bias-in-media/data/cleaned_articles_mass.csv')

# %%
bglobe_data.head()
# Out:
#   position_section position_subsection  \
# 0         BUSINESS             unknown
# 1                G         Living Arts
# 2             NEWS               Metro
# 3             NEWS               Metro
# 4             NEWS               Metro
#
#                                           hl1      hl2            author  \
# 0      cerezyme alternative gets fda approval  unknown  Associated Press
# 1                                     unknown  unknown      AMI ALBERNAZ
# 2                                     unknown  unknown           unknown
# 3  leave car home for first night, city urges  unknown           unknown
# 4                           a flawed calculus  unknown      Kevin Cullen
#
#                                                 lede  \
# 0  washington - the food and drug administration ...
# 1  earth-friendly sale porter square eco-boutique...
# 2       boston 96 orlando 84 celtics win series, 4-2
# 3  the mayor of boston and the city's top brass h...
# ...

# %%
unique_topics = bglobe_data['position_section'].value_counts()
num_topics = len(unique_topics)

print("Number of unique topics:", num_topics)
print("Number of articles correlated to each topic:")
print(unique_topics)
# Out:
# Number of unique topics: 16
# Number of articles correlated to each topic:
# NEWS                 50745
# LIVING ARTS          30543
# SPORTS               29071
# BUSINESS             27681
# EDITORIAL OPINION    15252
# REGIONAL             13367
# G                     4306
# MAGAZINE              3748
# SUNDAY                2963
# REALESTATE            1057
# unknown                 95
# DIVERSITY               19
# TABM                    14
# TAB2                     4
# PROJECT                  2
# ADVSUP                   1
# Name: position_section, dtype: int64

# %%
g_df = bglobe_data[bglobe_data['position_section'] == 'G']
g_df['position_section'] = g_df.apply(lambda row: row['position_subsection'] if row['position_section'] == 'G' else row['position_section'], axis=1)
unique_topics_g = g_df['position_section'].value_counts()
num_topics_g = len(unique_topics_g)

print("Number of unique topics:", num_topics_g)
print("Number of articles correlated to each topic:")
print(unique_topics_g)
# Out:
# Number of unique topics: 5
# Number of articles correlated to each topic:
# Living Arts    3936
# Food            359
# G                 9
# Metro             1
# unknown           1
# Name: position_section, dtype: int64
# /var/folders/gh/q7237klx1c30tt_49g13wllc0000gn/T/ipykernel_27184/1240734670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g_df['position_section'] = g_df.apply(lambda row: row['position_subsection'] if row['position_section'] == 'G' else row['position_section'], axis=1)

# %%
gg_df = g_df[g_df['position_section'] == 'G']
gg_df
# Out:
#       position_section position_subsection  \
# 333                  G                   G
# 2404                 G                   G
# 9570                 G                   G
# 15390                G                   G
# 17392                G                   G
# 18605                G                   G
# 20853                G                   G
# 22181                G                   G
# 23680                G                   G
#
#                                                      hl1  \
# 333                              cells unlike any others
# 2404   boston ballet's `la bayadère' breathtaking, he...
# 9570           `aftermath' brings iraq war close to home
# 15390                          james lets zoo go untamed
# 17392  novel touches in ballet's latest `romeo and ju...
# 18605            art's `ajax' runs afoul of its gimmicks
# 20853  monster jams kept coming, thanks to one star a...
# 22181                   ballet productions run hot, cold
# ...

# %%
news_df = bglobe_data[bglobe_data['position_section'] == 'NEWS']
unique_topics_news = news_df['position_subsection'].value_counts()
num_topics_news = len(unique_topics_news)

print("Number of unique topics:", num_topics_news)
print("Number of articles correlated to each topic:")
print(unique_topics_news)
# Out:
# Number of unique topics: 3
# Number of articles correlated to each topic:
# Metro            49109
# unknown           1620
# HealthScience       16
# Name: position_subsection, dtype: int64

# %%
news_df[news_df['position_subsection'] == 'unknown'].head(100)
# Out:
#       position_section position_subsection  \
# 107               NEWS             unknown
# 203               NEWS             unknown
# 238               NEWS             unknown
# 593               NEWS             unknown
# 613               NEWS             unknown
# ...                ...                 ...
# 11199             NEWS             unknown
# 11272             NEWS             unknown
# 11296             NEWS             unknown
# 11346             NEWS             unknown
# 11575             NEWS             unknown
#
#                                                      hl1  \
# 107       local sneaker firms are making it in indonesia
# 203                   they're just not the retiring type
# 238                                              unknown
# 593                        many must fend for themselves
# 613                                 sox spend up a storm
# ...                                                  ...
# ...

# %%
indexes = bglobe_data['indexing_terms']
bglobe_data.head()
# Out:
#   position_section position_subsection  \
# 0         BUSINESS             unknown
# 1                G         Living Arts
# 2             NEWS               Metro
# 3             NEWS               Metro
# 4             NEWS               Metro
#
#                                           hl1      hl2            author  \
# 0      cerezyme alternative gets fda approval  unknown  Associated Press
# 1                                     unknown  unknown      AMI ALBERNAZ
# 2                                     unknown  unknown           unknown
# 3  leave car home for first night, city urges  unknown           unknown
# 4                           a flawed calculus  unknown      Kevin Cullen
#
#                                                 lede  \
# 0  washington - the food and drug administration ...
# 1  earth-friendly sale porter square eco-boutique...
# 2       boston 96 orlando 84 celtics win series, 4-2
# 3  the mayor of boston and the city's top brass h...
# ...

# %%
bglobe_data['keywords'] = 'unknown'

# %%
import json

for index in range(len(indexes)):
    try:
        keywords = ""
        x = indexes[index].replace("'", "\"")
        res = json.loads(x)
        first_key = list(res.keys())[0]
        subjects = res[first_key]
        for subject in subjects:
            keyword = subject['className']
            keywords += keyword + " "
        bglobe_data.at[index, 'keywords'] = keywords
    except:
        print(index)
# Out:
# 1
# 27
# 43
# 52
# 54
# 115
# 118
# 124
# 137
# 142
# 143
# 163
# 171
# 174
# 192
# 209
# 210
# 212
# 243
# 256
# 260
# 265
# 279
# 299
# 302
# 303
# 332
# 333
# 365
# 378
# 411
# 416
# 419
# 452
# 454
# 526
# 544
# 553
# 555
# 566
# 580
# 582
# 608
# 615
# 658
# 659
# 663
# 727
# 780
# 812
# 816
# 820
# 851
# 868
# 890
# 901
# 907
# 911
# 928
# 960
# 966
# 969
# 1025
# 1040
# 1052
# 1077
# 1098
# 1117
# 1160
# 1165
# 1185
# 1197
# 1201
# 1231
# 1248
# 1274
# 1281
# 1284
# 1295
# 1327
# 1329
# 1337
# 1364
# 1379
# 1386
# 1399
# 1410
# 1440
# 1448
# 1456
# 1473
# 1475
# 1482
# 1494
# 1507
# 1537
# 1550
# 1578
# 1579
# 1594
# 1595
# 1603
# 1612
# 1618
# 1622
# 1623
# 1683
# 1711
# 1714
# 1738
# 1743
# 1744
# 1755
# 1817
# 1854
# 1855
# 1856
# 1864
# 1881
# 1900
# 1912
# 1916
# 1917
# 1921
# 1973
# 1995
# 2011
# 2012
# 2016
# 2044
# 2090
# 2098
# 2100
# 2109
# 2128
# 2134
# 2149
# 2165
# 2173
# 2175
# 2191
# 2193
# 2198
# 2200
# 2201
# 2207
# 2232
# 2240
# 2250
# 2296
# 2318
# 2326
# ...

# %%
bglobe_data.head()
# Out:
#   position_section position_subsection  \
# 0         BUSINESS             unknown
# 1                G         Living Arts
# 2             NEWS               Metro
# 3             NEWS               Metro
# 4             NEWS               Metro
#
#                                           hl1      hl2            author  \
# 0      cerezyme alternative gets fda approval  unknown  Associated Press
# 1                                     unknown  unknown      AMI ALBERNAZ
# 2                                     unknown  unknown           unknown
# 3  leave car home for first night, city urges  unknown           unknown
# 4                           a flawed calculus  unknown      Kevin Cullen
#
#                                                 lede  \
# 0  washington - the food and drug administration ...
# 1  earth-friendly sale porter square eco-boutique...
# 2       boston 96 orlando 84 celtics win series, 4-2
# 3  the mayor of boston and the city's top brass h...
# ...

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/iranjan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def get_sentiment_score(text):
    if pd.isna(text):
        return 0
    else:
        pols = sia.polarity_scores(text)
        return pols['compound']

# %%
bglobe_data['keyword_sentiment'] = 'unknown'
for index in range(len(bglobe_data)):
    keyword = bglobe_data.at[index, 'keywords']
    sentiment = get_sentiment_score(keyword)
    bglobe_data.at[index, 'keyword_sentiment'] = sentiment

# %%
bglobe_data.head()
# Out:
#   position_section position_subsection  \
# 0         BUSINESS             unknown
# 1                G         Living Arts
# 2             NEWS               Metro
# 3             NEWS               Metro
# 4             NEWS               Metro
#
#                                           hl1      hl2            author  \
# 0      cerezyme alternative gets fda approval  unknown  Associated Press
# 1                                     unknown  unknown      AMI ALBERNAZ
# 2                                     unknown  unknown           unknown
# 3  leave car home for first night, city urges  unknown           unknown
# 4                           a flawed calculus  unknown      Kevin Cullen
#
#                                                 lede  \
# 0  washington - the food and drug administration ...
# 1  earth-friendly sale porter square eco-boutique...
# 2       boston 96 orlando 84 celtics win series, 4-2
# 3  the mayor of boston and the city's top brass h...
# ...

# %%
bglobe_data[bglobe_data['keyword_sentiment'] != 0]
# Out:
#          position_section position_subsection  \
# 0                BUSINESS             unknown
# 3                    NEWS               Metro
# 4                    NEWS               Metro
# 5                    NEWS               Metro
# 6       EDITORIAL OPINION             Opinion
# ...                   ...                 ...
# 178840        LIVING ARTS             unknown
# 178848               NEWS               Metro
# 178855           BUSINESS             unknown
# 178859               NEWS               Metro
# 178861               NEWS               Metro
#
#                                                       hl1  \
# 0                  cerezyme alternative gets fda approval
# 3              leave car home for first night, city urges
# 4                                       a flawed calculus
# 5                                         advantage, kids
# 6       davis right to ask for da probe of police in r...
# ...

# %%
avg_sentiment_by_year = bglobe_data.groupby('year')['keyword_sentiment'].mean()
plt.rcParams['font.family'] = 'Times New Roman'

avg_sentiment_by_year.plot()
plt.xlabel('Year')
plt.ylabel('Average Opinion Metric for Key Words')
plt.title('Average Opinion Metric for Key Words Over Time')
plt.show()

# %%
bglobe_data
# Out:
#        position_section position_subsection  \
# 0              BUSINESS             unknown
# 1                     G         Living Arts
# 2                  NEWS               Metro
# 3                  NEWS               Metro
# 4                  NEWS               Metro
# ...                 ...                 ...
# 178863             NEWS               Metro
# 178864           SPORTS             unknown
# 178865      LIVING ARTS             unknown
# 178866           SPORTS             unknown
# 178867         BUSINESS             unknown
#
#                                                       hl1  \
# 0                  cerezyme alternative gets fda approval
# 1                                                 unknown
# 2                                                 unknown
# 3              leave car home for first night, city urges
# 4                                       a flawed calculus
# ...                                                   ...
# ...

# %%
bglobe_data['body_sentiment'] = 'unknown'
for index in range(len(bglobe_data)):
    body = bglobe_data.at[index, 'body_cleaned']
    body_sentiment = get_sentiment_score(body)
    bglobe_data.at[index, 'body_sentiment'] = body_sentiment

# %%
bglobe_data.head()
# Out:
#   position_section position_subsection  \
# 0         BUSINESS             unknown
# 1                G         Living Arts
# 2             NEWS               Metro
# 3             NEWS               Metro
# 4             NEWS               Metro
#
#                                           hl1      hl2            author  \
# 0      cerezyme alternative gets fda approval  unknown  Associated Press
# 1                                     unknown  unknown      AMI ALBERNAZ
# 2                                     unknown  unknown           unknown
# 3  leave car home for first night, city urges  unknown           unknown
# 4                           a flawed calculus  unknown      Kevin Cullen
#
#                                                 lede  \
# 0  washington - the food and drug administration ...
# 1  earth-friendly sale porter square eco-boutique...
# 2       boston 96 orlando 84 celtics win series, 4-2
# 3  the mayor of boston and the city's top brass h...
# ...

# %%
sentiment_data = bglobe_data.drop(bglobe_data[bglobe_data['keyword_sentiment'] == 'unknown'].index)
sentiment_data = sentiment_data.drop(sentiment_data[sentiment_data['body_sentiment'] == 'unknown'].index)

sentiment_data['keyword_sentiment'] = sentiment_data['keyword_sentiment'].astype(float)
sentiment_data['body_sentiment'] = sentiment_data['body_sentiment'].astype(float)
sentiment_data = sentiment_data.drop(sentiment_data[sentiment_data['keyword_sentiment'] == 0].index)

sentiment_data['keyword_sentiment'].corr(sentiment_data['body_sentiment'])
# Out:
# 0.4641827340374894

# %%
plt.scatter(sentiment_data['keyword_sentiment'], sentiment_data['body_sentiment'])
plt.xlabel('Keyword Sentiment')
plt.ylabel('Body Sentiment')
plt.title('Correlation between Keyword and Body Sentiment')
plt.show()

# %%
avg_body_sentiment_by_year = sentiment_data.groupby('year')['body_sentiment'].mean()
plt.rcParams['font.family'] = 'Times New Roman'

avg_body_sentiment_by_year.plot()
plt.xlabel('Year')
plt.ylabel('Average Opinion Metric for Article Bodies')
plt.title('Average Opinion Metric for Article Bodies Over Time')
plt.show()

# %%
plt.hist(sentiment_data['keyword_sentiment'], bins=20)
plt.xlabel('Opinion Metric for Key Words')
plt.ylabel('Frequency')
plt.title('Distribution of Opinion Metric for Key Words')
plt.show()

# %%
plt.hist(sentiment_data['body_sentiment'], bins=20)
plt.xlabel('Opinion Metric for Article Bodies')
plt.ylabel('Frequency')
plt.title('Distribution of Opinion Metric for Article Bodies')
plt.show()

# %%
# Out:
# 69198

# %%
len(body_sentiment)
# Out:
# 69198
