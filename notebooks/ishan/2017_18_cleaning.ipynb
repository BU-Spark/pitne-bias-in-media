# %%
# Main imports
import pandas as pd
import numpy as np
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import os, sys
import seaborn as sns
from tqdm import tqdm
from copy import deepcopy
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Read the CSVs
data_2017 = pd.read_csv('/Users/iranjan/Projects/dd4g-bias-in-media/data/2017_articles_mass.csv')
data_2018 = pd.read_csv('/Users/iranjan/Projects/dd4g-bias-in-media/data/2018_articles_mass.csv')

# %%
data_2017.head()
# Out:
#    Unnamed: 0 position_section position_subsection  \
# 0         183      LIVING ARTS                 NaN
# 1         195           SPORTS                 NaN
# 2         203         REGIONAL                West
# 3         205         REGIONAL                West
# 4         207           SUNDAY              Travel
#
#                                                  hl1              hl2 author  \
# 0                                              Music              NaN    NaN
# 1                                     Duke 93, BC 82              NaN    NaN
# 2                                       CAMPUS ANGLE  DAVID OLUWADARA    NaN
# 3                                         NOTEWORTHY              NaN    NaN
# 4  Broadway actor enjoys visiting places with old...              NaN    NaN
#
#                                                 lede  \
# 0  sub rosa: songs from three mile island remembe...
# 1  at cameron indoor stadium, durham, n.c. boston...
# 2  a repeat patriot league men's indoor field ath...
# 3  cal howes maynard the freshman basketball guar...
# 4  rob mcclure with his wife, maggie lakis, in ve...
#
#                                                 body  word_count  \
# 0  godheadsilo this fargo, n.d.-born duo, embarki...      2003.0
# 1  jeffers 29 3-4 2-2 4-12 1 1 8 turner 35 5-9 2-...       229.0
# 2  last february at bu's valentine invitational, ...       734.0
# 3  jennifer narlee medfield narlee was named new ...       157.0
# 4   favorite vacation destination? venice. i love...       497.0
#
#                                     content-id    pub_date  \
# 0  BGLOBE-2a68b240-d1d9-11e6-b500-ed0ab7c07c6a  2017-01-08
# 1  BGLOBE-7b4a7670-d522-11e6-b500-ed0ab7c07c6a  2017-01-08
# 2  BGLOBE-d61f6ee0-ce0e-11e6-b750-b206eb104cd9  2017-01-08
# 3  BGLOBE-995230a0-ce0f-11e6-b750-b206eb104cd9  2017-01-08
# 4  BGLOBE-31a8a19c-d106-11e6-b500-ed0ab7c07c6a  2017-01-08
#
#                                       indexing_terms  year
# 0  {'subject': [{'score': '90', 'classCode': 'ST0...  2017
# 1  {'legal': [{'className': 'Bankruptcy Law', 'cl...  2017
# 2  {'legal': [{'className': 'Education Law', 'cla...  2017
# 3  {'subject': [{'score': '90', 'classCode': 'STX...  2017
# 4  {'subject': [{'score': '78', 'classCode': 'ST0...  2017

# %%
data_2018.head()
# Out:
#    Unnamed: 0 position_section position_subsection  \
# 0           0           SPORTS                 NaN
# 1           7             NEWS               Metro
# 2          19         BUSINESS                 NaN
# 3          24           SPORTS                 NaN
# 4          25             NEWS               Metro
#
#                                               hl1  \
# 0            Team up in air on Canada's pot issue
# 1  Out of chaos, a candidate shouting to be heard
# 2            Walsh looking for climate plan funds
# 3                               Baseball playoffs
# 4              Harvard decisions benefited donors
#
#                                                  hl2 author  \
# 0                                                NaN    NaN
# 1  Trump-backer Ayyadurai lags in race for Senate...    NaN
# 2                                                NaN    NaN
# 3                                                NaN    NaN
# 4            Bias suit highlights admissions process    NaN
#
#                                                 lede  \
# 0  calgary, alberta — some bruins rely on plant-b...
# 1  shiva ayyadurai election day is several weeks ...
# 2  business leaders seem ready to embrace marty w...
# 3  game 1 astros 7, red sox 2 game 2 red sox 7, a...
# 4  when harvard university admitted several appli...
#
#                                                 body  word_count  \
# 0  body while now legal in 13 nhl cities — seven ...       912.0
# 1  body there's name-calling. ayyadurai calls sen...      1456.0
# 2  body the mayor received a prolonged standing o...       547.0
# 3                                               body        44.0
# 4  body ellwood lauded fitzsimmons on "big wins,"...      1172.0
#
#                                     content-id    pub_date  \
# 0  BGLOBE-1a045630-d24e-11e8-83d5-dee7c961b652  2018-10-18
# 1  BGLOBE-1765cf42-c201-11e8-9dad-d8665da1fb0e  2018-10-18
# 2  BGLOBE-7339aaec-d24f-11e8-83d5-dee7c961b652  2018-10-18
# 3  BGLOBE-2f273fb2-d250-11e8-8fdb-5c3af1605444  2018-10-18
# 4  BGLOBE-138deca0-d24c-11e8-8fdb-5c3af1605444  2018-10-18
#
#                                       indexing_terms  year
# 0  {'subject': [{'score': '92', 'classCode': 'STX...  2018
# 1  {'legal': [{'className': 'Governments', 'class...  2018
# 2  {'subject': [{'score': '89', 'classCode': 'ST0...  2018
# 3  {'legal': [{'className': 'Business & Corporate...  2018
# 4  {'legal': [{'className': 'Education Law', 'cla...  2018

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/iranjan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data_2017 = data_2017.fillna('unknown')
data_2018 = data_2018.fillna('unknown')

# %%
def clean_data(df):

    tqdm.pandas()
    # Create a copy of the dataframe to return
    df_toclean = df.copy()

    # Remove first column that is unnamed, as well as content-id column
    df_toclean = df_toclean.drop(columns=['Unnamed: 0', 'content-id', 'word_count'])

    # Make all text lowercase in hl1 hl2 lede body columns 
    df_toclean['hl1'] = df_toclean['hl1'].str.lower()
    df_toclean['hl2'] = df_toclean['hl2'].str.lower()
    df_toclean['lede'] = df_toclean['lede'].str.lower()
    df_toclean['body'] = df_toclean['body'].str.lower()

    # Remove extra whitespace in hl1 hl2 lede body columns 
    df_toclean['hl1'] = df_toclean['hl1'].str.strip()
    df_toclean['hl2'] = df_toclean['hl2'].str.strip()
    df_toclean['lede'] = df_toclean['lede'].str.strip()
    df_toclean['body'] = df_toclean['body'].str.strip()

    # If the body only has the word 'body', replace it with the lede
    df_toclean.loc[df_toclean['body'] == 'body', 'body'] = df_toclean['lede']

    # Clean Bodies using Regex
    # func_clean_body_no_punct = lambda x: ' '.join([item for item in re.findall(r'[A-Za-z0-9]+', x) if len(item) > 1])
    # df_toclean['body_cleaned'] = df_toclean['body'].progress_apply(func_clean_body_no_punct)

    # Do an actual word count
    func_count_words = lambda x: len(x.split())
    df['actual_body_word_count'] = df['body'].progress_apply(func_count_words)

    # Clean Bodies using Regex
    func_clean_body = lambda x: ' '.join(re.findall(r'[A-Za-z0-9!@#$%^&*()]+.', x))
    df['body_cleaned'] = df['body'].progress_apply(func_clean_body)

    # Before stop words: create a column actual_body_word_count that has the true word count of the body BEFORE it is cleaned and words are removed 
    nltk.download('stopwords')

    stop_words = set(stopwords.words('english'))
    
    func_remove_stop = lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words])
    df_toclean['body_cleaned'] = df_toclean['body_cleaned'].progress_apply(func_remove_stop)

    return df_toclean

# %%
data_2018_cleaned = clean_data(data_2018)
# Out:
# 100%|██████████| 12287/12287 [00:00<00:00, 42093.47it/s]
# 100%|██████████| 12287/12287 [00:00<00:00, 12435.55it/s]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/iranjan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 100%|██████████| 12287/12287 [00:35<00:00, 347.61it/s]

# %%
data_2018_cleaned.head()
# Out:
#   position_section position_subsection  \
# 0           SPORTS             unknown
# 1             NEWS               Metro
# 2         BUSINESS             unknown
# 3           SPORTS             unknown
# 4             NEWS               Metro
#
#                                               hl1  \
# 0            team up in air on canada's pot issue
# 1  out of chaos, a candidate shouting to be heard
# 2            walsh looking for climate plan funds
# 3                               baseball playoffs
# 4              harvard decisions benefited donors
#
#                                                  hl2   author  \
# 0                                            unknown  unknown
# 1  trump-backer ayyadurai lags in race for senate...  unknown
# 2                                            unknown  unknown
# 3                                            unknown  unknown
# 4            bias suit highlights admissions process  unknown
#
#                                                 lede  \
# 0  calgary, alberta — some bruins rely on plant-b...
# 1  shiva ayyadurai election day is several weeks ...
# 2  business leaders seem ready to embrace marty w...
# 3  game 1 astros 7, red sox 2 game 2 red sox 7, a...
# 4  when harvard university admitted several appli...
#
#                                                 body    pub_date  \
# 0  body while now legal in 13 nhl cities — seven ...  2018-10-18
# 1  body there's name-calling. ayyadurai calls sen...  2018-10-18
# 2  body the mayor received a prolonged standing o...  2018-10-18
# 3  game 1 astros 7, red sox 2 game 2 red sox 7, a...  2018-10-18
# 4  body ellwood lauded fitzsimmons on "big wins,"...  2018-10-18
#
#                                       indexing_terms  year  \
# 0  {'subject': [{'score': '92', 'classCode': 'STX...  2018
# 1  {'legal': [{'className': 'Governments', 'class...  2018
# 2  {'subject': [{'score': '89', 'classCode': 'ST0...  2018
# 3  {'legal': [{'className': 'Business & Corporate...  2018
# 4  {'legal': [{'className': 'Education Law', 'cla...  2018
#
#    actual_body_word_count                                       body_cleaned
# 0                     837  body legal 13 nhl cities seven canada , three ...
# 1                    1329  body ' name- calling . ayyadurai calls senator...
# 2                     497  body mayor received prolonged standing ovation...
# 3                       1                                               body
# 4                     964  body ellwood lauded fitzsimmons big wins , inc...

# %%
data_2017_cleaned = clean_data(data_2017)
# Out:
# 100%|██████████| 15294/15294 [00:00<00:00, 43611.06it/s]
# 100%|██████████| 15294/15294 [00:01<00:00, 12956.75it/s]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/iranjan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 100%|██████████| 15294/15294 [00:42<00:00, 358.58it/s]

# %%
data_2017_cleaned.head()
# Out:
#   position_section position_subsection  \
# 0      LIVING ARTS             unknown
# 1           SPORTS             unknown
# 2         REGIONAL                West
# 3         REGIONAL                West
# 4           SUNDAY              Travel
#
#                                                  hl1              hl2  \
# 0                                              music          unknown
# 1                                     duke 93, bc 82          unknown
# 2                                       campus angle  david oluwadara
# 3                                         noteworthy          unknown
# 4  broadway actor enjoys visiting places with old...          unknown
#
#     author                                               lede  \
# 0  unknown  sub rosa: songs from three mile island remembe...
# 1  unknown  at cameron indoor stadium, durham, n.c. boston...
# 2  unknown  a repeat patriot league men's indoor field ath...
# 3  unknown  cal howes maynard the freshman basketball guar...
# 4  unknown  rob mcclure with his wife, maggie lakis, in ve...
#
#                                                 body    pub_date  \
# 0  godheadsilo this fargo, n.d.-born duo, embarki...  2017-01-08
# 1  jeffers 29 3-4 2-2 4-12 1 1 8 turner 35 5-9 2-...  2017-01-08
# 2  last february at bu's valentine invitational, ...  2017-01-08
# 3  jennifer narlee medfield narlee was named new ...  2017-01-08
# 4  favorite vacation destination? venice. i loved...  2017-01-08
#
#                                       indexing_terms  year  \
# 0  {'subject': [{'score': '90', 'classCode': 'ST0...  2017
# 1  {'legal': [{'className': 'Bankruptcy Law', 'cl...  2017
# 2  {'legal': [{'className': 'Education Law', 'cla...  2017
# 3  {'subject': [{'score': '90', 'classCode': 'STX...  2017
# 4  {'subject': [{'score': '78', 'classCode': 'ST0...  2017
#
#    actual_body_word_count                                       body_cleaned
# 0                    1624  godheadsilo fargo , n. d. born duo , embarking...
# 1                     264  jeffers 29 3- 4 2- 2 4- 12 1 1 8 turner 35 5- ...
# 2                     694  last february bu ' valentine invitational , ne...
# 3                      93  jennifer narlee medfield narlee named new engl...
# 4                     301  favorite vacation destination ? venice . loved...

# %%
data_2017_cleaned.to_csv('/Users/iranjan/Projects/dd4g-bias-in-media/data/cleaned_data_2017.csv', index=False)
data_2018_cleaned.to_csv('/Users/iranjan/Projects/dd4g-bias-in-media/data/cleaned_data_2018.csv', index=False)
